# %%
# %pylab inline
import random
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def myMonteCarlo(N, betaJ):
    
    mTar= []
    m2Tar=[]
    spins = ones(N) #tömb N db spin tárolására
                    #szélső helyzetből indulunk
    
    jRelax =0
    j =0
    while j<1500: 
        mySpin=random.randint(0,49) #véletlesnszerűen kiválasztok egy spint
        if mySpin==0:
            deltaE = spins[mySpin]*(spins[49]+spins[mySpin+1]) #energiaváltozás
                                                #sorsolt és sorsolttal szomszédos
                                                #spinekből
        elif mySpin==49:
            deltaE = spins[mySpin]*(spins[mySpin-1]+spins[0]) #energiaváltozás
                                                #sorsolt és sorsolttal szomszédos  
                                                #spinekből
        else:
            deltaE = spins[mySpin]*(spins[mySpin-1]+spins[mySpin+1]) #energiaváltozás
                                                #sorsolt és sorsolttal szomszédos
                                                #spinekből
                                                                                                
        if deltaE<0:
            spins[mySpin]=-spins[mySpin] #forgatás
                
        elif deltaE==0:
            P=random.random() #véletlen valós sorsolása [0,1]-ből
            if P<0.5:
                spins[mySpin]=-spins[mySpin] #forgatás
            elif P>0.5:
                spins[mySpin]=spins[mySpin]
                
        else:
            P=random.random() #véletlen valós sorsolása [0,1]-ből
            if mySpin==0:
                expValue=exp(-2*betaJ*spins[mySpin]*(spins[49]+spins[mySpin+1]))
                
            elif mySpin==49:
                expValue=exp(-2*betaJ*spins[mySpin]*(spins[mySpin-1]+spins[0]))
            
            else:
                expValue=exp(-2*betaJ*spins[mySpin]*(spins[mySpin-1]+spins[mySpin+1]))
            
            if P<expValue:
                spins[mySpin]=-spins[mySpin] #forgatás
            else:    
                spins[mySpin]=spins[mySpin]     
        
        
        if (jRelax==0)&(mean(spins)==0):
            jRelax= j
            print('Relaxációs idő: ', jRelax+1)
            
        if (jRelax!=0)&(j>=jRelax+1):
            mTar.append(mean(spins))
            m2Tar.append(mean(spins)**2)
            
        j+=1
    
    
    print('mágnesezettség időátlaga: ',mean(array(mTar)))
    print('mágnesezettség négyzetének időátlaga: ',mean(array(m2Tar)))
    return spins

# %% [markdown]
# #### 3 mérés $\beta J = 0.08$ esetére

# %%
spins11=myMonteCarlo(50, 0.08)
gridSpins11=array([x for x in range(1,spins11.shape[0]+1)])
plot(gridSpins11,spins11,'.', label=r'$\beta J = 0.08$')
grid()
xlabel(r'$s_i$', fontsize=14)
ylabel('spin értéke', fontsize=14)
legend(prop={'size': 14})
savefig('spins11.png')
# Out:
# Relaxációs idő:  112
# mágnesezettség időátlaga:  0.043948126801152745
# mágnesezettség négyzetének időátlaga:  0.0263850144092219

# %%
spins12=myMonteCarlo(50, 0.08)
gridSpins12=array([x for x in range(1,spins12.shape[0]+1)])
plot(gridSpins12,spins12,'.', label=r'$\beta J = 0.08$')
grid()
xlabel(r'$s_i$', fontsize=14)
ylabel('spin értéke', fontsize=14)
legend(prop={'size': 14})
savefig('spins12.png')
# Out:
# Relaxációs idő:  172
# mágnesezettség időátlaga:  0.02069277108433735
# mágnesezettség négyzetének időátlaga:  0.01783253012048193

# %%
spins13=myMonteCarlo(50, 0.08)
gridSpins13=array([x for x in range(1,spins13.shape[0]+1)])
plot(gridSpins13,spins13,'.', label=r'$\beta J = 0.08$')
grid()
xlabel(r'$s_i$', fontsize=14)
ylabel('spin értéke', fontsize=14)
legend(prop={'size': 14})
savefig('spins13.png')
# Out:
# Relaxációs idő:  66
# mágnesezettség időátlaga:  0.05517433751743375
# mágnesezettség négyzetének időátlaga:  0.02154309623430962

# %% [markdown]
# #### 3 mérés $\beta J = 0.20$ esetére

# %%
spins21=myMonteCarlo(50, 0.20)
gridSpins21=array([x for x in range(1,spins21.shape[0]+1)])
plot(gridSpins21,spins21,'.', label=r'$\beta J = 0.20$')
grid()
xlabel(r'$s_i$', fontsize=14)
ylabel('spin értéke', fontsize=14)
legend(prop={'size': 14})
savefig('spins21.png')
# Out:
# Relaxációs idő:  97
# mágnesezettség időátlaga:  -0.04701354240912331
# mágnesezettség négyzetének időátlaga:  0.032774340698503206

# %%
spins22=myMonteCarlo(50, 0.20)
gridSpins22=array([x for x in range(1,spins22.shape[0]+1)])
plot(gridSpins22,spins22,'.', label=r'$\beta J = 0.20$')
grid()
xlabel(r'$s_i$', fontsize=14)
ylabel('spin értéke', fontsize=14)
legend(prop={'size': 14})
savefig('spins22.png')
# Out:
# Relaxációs idő:  157
# mágnesezettség időátlaga:  -0.08312732688011915
# mágnesezettség négyzetének időátlaga:  0.037116902457185415

# %%
spins23=myMonteCarlo(50, 0.20)
gridSpins23=array([x for x in range(1,spins23.shape[0]+1)])
plot(gridSpins23,spins23,'.', label=r'$\beta J = 0.20$')
grid()
xlabel(r'$s_i$', fontsize=14)
ylabel('spin értéke', fontsize=14)
legend(prop={'size': 14})
savefig('spins23.png')
# Out:
# Relaxációs idő:  76
# mágnesezettség időátlaga:  0.014297752808988762
# mágnesezettség négyzetének időátlaga:  0.03043483146067416

# %% [markdown]
# #### 3 mérés $\beta J = 0.45$ esetére

# %%
spins31=myMonteCarlo(50, 0.45)
gridSpins31=array([x for x in range(1,spins31.shape[0]+1)])
plot(gridSpins31,spins31,'.', label=r'$\beta J = 0.45$')
grid()
xlabel(r'$s_i$', fontsize=14)
ylabel('spin értéke', fontsize=14)
legend(prop={'size': 14})
savefig('spins31.png')
# Out:
# Relaxációs idő:  707
# mágnesezettség időátlaga:  0.11778058007566207
# mágnesezettség négyzetének időátlaga:  0.05949861286254729

# %%
spins32=myMonteCarlo(50, 0.45)
gridSpins32=array([x for x in range(1,spins32.shape[0]+1)])
plot(gridSpins32,spins32,'.', label=r'$\beta J = 0.45$')
grid()
xlabel(r'$s_i$', fontsize=14)
ylabel('spin értéke', fontsize=14)
legend(prop={'size': 14})
savefig('spins32.png')
# Out:
# Relaxációs idő:  251
# mágnesezettség időátlaga:  -0.04275420336269015
# mágnesezettség négyzetének időátlaga:  0.0379298638911129

# %%
spins33=myMonteCarlo(50, 0.45)
gridSpins33=array([x for x in range(1,spins33.shape[0]+1)])
plot(gridSpins33,spins33,'.', label=r'$\beta J = 0.45$')
grid()
xlabel(r'$s_i$', fontsize=14)
ylabel('spin értéke', fontsize=14)
legend(prop={'size': 14})
savefig('spins33.png')
# Out:
# Relaxációs idő:  235
# mágnesezettség időátlaga:  -0.13065612648221347
# mágnesezettség négyzetének időátlaga:  0.04302671936758894

# %% [markdown]
# #### 3 mérés $\beta J = 0.85$ esetére

# %%
spins41=myMonteCarlo(50, 0.85)
gridSpins41=array([x for x in range(1,spins41.shape[0]+1)])
plot(gridSpins41,spins41,'.', label=r'$\beta J = 0.85$')
grid()
xlabel(r'$s_i$', fontsize=14)
ylabel('spin értéke', fontsize=14)
legend(prop={'size': 14})
savefig('spins41.png')
# Out:
# Relaxációs idő:  1188
# mágnesezettség időátlaga:  -0.22423076923076926
# mágnesezettség négyzetének időátlaga:  0.05932820512820513

# %%
spins42=myMonteCarlo(50, 0.85)
gridSpins42=array([x for x in range(1,spins42.shape[0]+1)])
plot(gridSpins42,spins42,'.', label=r'$\beta J = 0.85$')
grid()
xlabel(r'$s_i$', fontsize=14)
ylabel('spin értéke', fontsize=14)
legend(prop={'size': 14})
savefig('spins42.png')
# Out:
# Relaxációs idő:  1347
# mágnesezettség időátlaga:  -0.13673202614379087
# mágnesezettség négyzetének időátlaga:  0.02255686274509804

# %%
spins43=myMonteCarlo(50, 0.85)
gridSpins43=array([x for x in range(1,spins43.shape[0]+1)])
plot(gridSpins43,spins43,'.', label=r'$\beta J = 0.85$')
grid()
xlabel(r'$s_i$', fontsize=14)
ylabel('spin értéke', fontsize=14)
legend(prop={'size': 14})
savefig('spins43.png')
# Out:
# Relaxációs idő:  592
# mágnesezettség időátlaga:  -0.015991189427312782
# mágnesezettség négyzetének időátlaga:  0.007804405286343612
